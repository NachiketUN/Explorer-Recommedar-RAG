# %%
! pip install rank-bm25
# Out:
# Requirement already satisfied: rank-bm25 in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (0.2.2)
# Requirement already satisfied: numpy in /Library/Frameworks/Python.framework/Versions/3.11/lib/python3.11/site-packages (from rank-bm25) (1.26.0)
#
# [notice] A new release of pip is available: 23.2.1 -> 24.0
# [notice] To update, run: pip install --upgrade pip

# %%
import pickle
import pandas as pd

# %%
with open('houston_rest_df.pickle', 'rb') as f:
    business_df = pickle.load(f)

# %%
with open('houston_restaurent_reviews.pickle', 'rb') as f:
    reviews_df = pickle.load(f)

# %%
reviews_df.head(3)
# Out:
#                  user_id           name           time  rating  \
# 0  108973466903602523839     Candi Redd  1629502461357       5
# 1  113137095513792040022  Paul Gantcher  1629052063842       5
# 2  105026170218579952045      Rio Abbas  1630887172418       4
#
#                                                 text  \
# 0  Yes 🙌🏽. I got the curry chicken with a number ...
# 1  Absolutely love this new location. Food tastes...
# 2  This location just opened and is super clean. ...
#
#                                                 pics  \
# 0  [{'url': ['https://lh5.googleusercontent.com/p...
# 1  [{'url': ['https://lh5.googleusercontent.com/p...
# 2                                               None
#
#                                                 resp  \
# 0                                               None
# 1                                               None
# 2  {'time': 1630948490198, 'text': 'Hi Rio! Thank...
#
#                                  gmap_id
# 0  0x8640c346cda31ecf:0xdccfb2cdf28f02dc
# 1  0x8640c346cda31ecf:0xdccfb2cdf28f02dc
# 2  0x8640c346cda31ecf:0xdccfb2cdf28f02dc

# %%
business_df.head(3)
# Out:
#             name                                            address  \
# 355       Fadi's      Fadi's, 6365 Westheimer Rd, Houston, TX 77057
# 356     Jus' Mac    Jus' Mac, 5640 Westheimer Rd, Houston, TX 77056
# 784  chill works  chill works, 3509 Elgin St Suite 200, Houston,...
#
#                                    gmap_id description   latitude  longitude  \
# 355  0x8640c346cda31ecf:0xdccfb2cdf28f02dc        None  29.737234 -95.496488
# 356  0x8640c15f393c8e2b:0xcebbc17fcff328bf        None  29.738526 -95.475659
# 784  0x8640bfa9613de5f1:0xf720305f9ba54d81        None  29.728121 -95.349025
#
#                                               category  avg_rating  \
# 355                         [Mediterranean restaurant]         4.7
# 356                              [American restaurant]         4.5
# 784  [Frozen yogurt shop, Dessert shop, Frozen dess...         4.9
#
#      num_of_reviews  price                                              hours  \
# 355              18      0  [[Wednesday, 11AM–9PM], [Thursday, 11AM–9PM], ...
# 356              16      0  [[Wednesday, 11:30AM–9PM], [Thursday, 11:30AM–...
# 784              28      0  [[Wednesday, 12–8PM], [Thursday, 12–8PM], [Fri...
#
#                                                   MISC  \
# 355  {'Service options': ['Takeout', 'Dine-in', 'De...
# 356  {'Service options': ['Delivery', 'Takeout', 'D...
# 784  {'From the business': ['Identifies as Black-ow...
#
#                           state relative_results  \
# 355     Closed ⋅ Opens 11AM Thu             None
# 356  Closed ⋅ Opens 11:30AM Thu             None
# 784           Open ⋅ Closes 8PM             None
#
#                                                    url
# 355  https://www.google.com/maps/place//data=!4m2!3...
# 356  https://www.google.com/maps/place//data=!4m2!3...
# 784  https://www.google.com/maps/place//data=!4m2!3...

# %%
merged_business_review_df = pd.merge(business_df, reviews_df, on='gmap_id', how='inner')

# %%
merged_business_review_df.head(4)
# Out:
#    name_x                                        address  \
# 0  Fadi's  Fadi's, 6365 Westheimer Rd, Houston, TX 77057
# 1  Fadi's  Fadi's, 6365 Westheimer Rd, Houston, TX 77057
# 2  Fadi's  Fadi's, 6365 Westheimer Rd, Houston, TX 77057
# 3  Fadi's  Fadi's, 6365 Westheimer Rd, Houston, TX 77057
#
#                                  gmap_id description   latitude  longitude  \
# 0  0x8640c346cda31ecf:0xdccfb2cdf28f02dc        None  29.737234 -95.496488
# 1  0x8640c346cda31ecf:0xdccfb2cdf28f02dc        None  29.737234 -95.496488
# 2  0x8640c346cda31ecf:0xdccfb2cdf28f02dc        None  29.737234 -95.496488
# 3  0x8640c346cda31ecf:0xdccfb2cdf28f02dc        None  29.737234 -95.496488
#
#                      category  avg_rating  num_of_reviews  price  ...  \
# 0  [Mediterranean restaurant]         4.7              18      0  ...
# 1  [Mediterranean restaurant]         4.7              18      0  ...
# 2  [Mediterranean restaurant]         4.7              18      0  ...
# 3  [Mediterranean restaurant]         4.7              18      0  ...
#
#                      state relative_results  \
# 0  Closed ⋅ Opens 11AM Thu             None
# 1  Closed ⋅ Opens 11AM Thu             None
# 2  Closed ⋅ Opens 11AM Thu             None
# 3  Closed ⋅ Opens 11AM Thu             None
#
#                                                  url                user_id  \
# 0  https://www.google.com/maps/place//data=!4m2!3...  108973466903602523839
# 1  https://www.google.com/maps/place//data=!4m2!3...  113137095513792040022
# 2  https://www.google.com/maps/place//data=!4m2!3...  105026170218579952045
# 3  https://www.google.com/maps/place//data=!4m2!3...  117177685398357548836
#
#           name_y           time rating  \
# 0     Candi Redd  1629502461357      5
# 1  Paul Gantcher  1629052063842      5
# 2      Rio Abbas  1630887172418      4
# 3  Jaleh Sadeghi  1629873058680      5
#
#                                                 text  \
# 0  Yes 🙌🏽. I got the curry chicken with a number ...
# 1  Absolutely love this new location. Food tastes...
# 2  This location just opened and is super clean. ...
# 3  I am so happy that they open the new location!...
#
#                                                 pics  \
# 0  [{'url': ['https://lh5.googleusercontent.com/p...
# 1  [{'url': ['https://lh5.googleusercontent.com/p...
# 2                                               None
# 3                                               None
#
#                                                 resp
# 0                                               None
# 1                                               None
# 2  {'time': 1630948490198, 'text': 'Hi Rio! Thank...
# 3                                               None
#
# [4 rows x 22 columns]

# %%
merged_business_review_df = merged_business_review_df.dropna(subset=['text'])

# %%
merged_review_df = merged_business_review_df.groupby('gmap_id')['text'].apply(lambda x: ' '.join(x)).reset_index()

# %%
merged_review_df.head(5)
# Out:
#                                  gmap_id  \
# 0  0x145e90b5d53fcc9d:0x2ae4bdf777e04ee3
# 1  0x145e972e8a6d31ff:0x78d7b66e8861c3d3
# 2  0x145e9b56da9601ad:0x1dbdccbfc0ec8184
# 3  0x145ec14420418d4f:0x204b57b935cbab8b
# 4  0x145ec1444ba9377f:0x1ed10c0f7381e31d
#
#                                                 text
# 0  CDC Guidelines A Pass!! But! I wanted to eat h...
# 1  Meh. Good but not blown away. Service was quic...
# 2  Great pork bahn mi and had a bowl of the #14 p...
# 3  Attitude is very dry. Looking over menu was ru...
# 4  Ask for Jalapino chiken yummy Great for lunch ...

# %%
doc_df = pd.merge(business_df, merged_review_df, on='gmap_id', how='inner')

# %%
doc_df
# Out:
#                                             name  \
# 0                                         Fadi's
# 1                                       Jus' Mac
# 2                                    chill works
# 3                 Tacos Adrian's Puerto Vallarta
# 4                          Fire Wings Westheimer
# ...                                          ...
# 6999                         Pappasito's Cantina
# 7000                                Krispy Kreme
# 7001                          E-Tao Asian Eatery
# 7002                         Go Go Curry Houston
# 7003  Houston Livestock Show and Rodeo Boardroom
#
#                                                 address  \
# 0         Fadi's, 6365 Westheimer Rd, Houston, TX 77057
# 1       Jus' Mac, 5640 Westheimer Rd, Houston, TX 77056
# 2     chill works, 3509 Elgin St Suite 200, Houston,...
# 3     Tacos Adrian's Puerto Vallarta, 9705 Synott Rd...
# 4     Fire Wings Westheimer, 8401 Westheimer Rd #110...
# ...                                                 ...
# 6999  Pappasito's Cantina, Hilton Americas, 1600 Lam...
# 7000  Krispy Kreme, 8611 Westheimer Rd, Houston, TX ...
# 7001  E-Tao Asian Eatery, 5135 W Alabama St #7295, H...
# 7002  Go Go Curry Houston, 9889 Bellaire Blvd Suite ...
# 7003  Houston Livestock Show and Rodeo Boardroom, NR...
#
#                                     gmap_id  \
# 0     0x8640c346cda31ecf:0xdccfb2cdf28f02dc
# 1     0x8640c15f393c8e2b:0xcebbc17fcff328bf
# 2     0x8640bfa9613de5f1:0xf720305f9ba54d81
# 3      0x8640dd873932f3cb:0x1d55512b687664e
# 4     0x8640c35c5577dd3b:0x6f468afe463fd1aa
# ...                                     ...
# 6999  0x8640bf22f4a3137d:0xc9c89014d4d23168
# 7000  0x8640c3a739a4a165:0x51d500b092866a00
# 7001  0x8640c16ef4e7ffef:0xb4aaa7594e77f42f
# 7002  0x8640c34983e7bf7f:0xfb70b0ce1aaa703d
# 7003  0x8640c01bad70a333:0x9a21d4763ab9353f
#
#                                             description   latitude  longitude  \
# 0                                                  None  29.737234 -95.496488
# 1                                                  None  29.738526 -95.475659
# 2                                                  None  29.728121 -95.349025
# 3                                                  None  29.674672 -95.613862
# 4                                                  None  29.736600 -95.514498
# ...                                                 ...        ...        ...
# 6999  Tex-Mex dishes & margaritas are the stars at t...  29.751927 -95.361120
# 7000  Longtime chain serving a variety of donut flav...  29.736951 -95.518211
# 7001  Contemporary eatery in a retail mall offering ...  29.736558 -95.463934
# 7002                                               None  29.702647 -95.553408
# 7003                                               None  29.686891 -95.408730
#
#                                                category  avg_rating  \
# 0                            [Mediterranean restaurant]         4.7
# 1                                 [American restaurant]         4.5
# 2     [Frozen yogurt shop, Dessert shop, Frozen dess...         4.9
# 3                                          [Restaurant]         4.4
# 4                [Chicken wings restaurant, Restaurant]         4.0
# ...                                                 ...         ...
# 6999                               [Mexican restaurant]         4.2
# 7000  [Donut shop, Coffee shop, Dessert shop, Fast f...         3.9
# 7001                     [Asian restaurant, Restaurant]         4.0
# 7002                        [Japanese curry restaurant]         4.0
# 7003                                       [Restaurant]         4.3
#
#       num_of_reviews  price  \
# 0                 18      0
# 1                 16      0
# 2                 28      0
# 3                 28      0
# 4                 75      2
# ...              ...    ...
# 6999            1894      2
# 7000            1767      1
# 7001             166      0
# 7002             178      0
# 7003              64      0
#
#                                                   hours  \
# 0     [[Wednesday, 11AM–9PM], [Thursday, 11AM–9PM], ...
# 1     [[Wednesday, 11:30AM–9PM], [Thursday, 11:30AM–...
# 2     [[Wednesday, 12–8PM], [Thursday, 12–8PM], [Fri...
# 3     [[Wednesday, 2:30–11:30PM], [Thursday, 2:30–11...
# 4     [[Wednesday, 11AM–10PM], [Thursday, 11AM–10PM]...
# ...                                                 ...
# 6999  [[Thursday, 4–9PM], [Friday, 4–9PM], [Saturday...
# 7000  [[Thursday, 6AM–10PM], [Friday, 6AM–11PM], [Sa...
# 7001  [[Thursday, 10AM–9PM], [Friday, 10AM–9PM], [Sa...
# 7002  [[Thursday, 10:55AM–9PM], [Friday, 10:55AM–9PM...
# 7003                                               None
#
#                                                    MISC  \
# 0     {'Service options': ['Takeout', 'Dine-in', 'De...
# 1     {'Service options': ['Delivery', 'Takeout', 'D...
# 2     {'From the business': ['Identifies as Black-ow...
# 3     {'Service options': ['Takeout', 'Dine-in', 'De...
# 4     {'Service options': ['Delivery', 'Takeout', 'D...
# ...                                                 ...
# 6999  {'Service options': ['Outdoor seating', 'Curbs...
# 7000  {'Service options': ['Curbside pickup', 'Deliv...
# 7001                  {'Service options': ['Delivery']}
# 7002  {'Service options': ['Delivery', 'Takeout', 'D...
# 7003  {'Service options': ['Delivery'], 'Health & sa...
#
#                            state  \
# 0        Closed ⋅ Opens 11AM Thu
# 1     Closed ⋅ Opens 11:30AM Thu
# 2              Open ⋅ Closes 8PM
# 3          Closed ⋅ Opens 2:30PM
# 4            Closed ⋅ Opens 11AM
# ...                          ...
# 6999                         NaN
# 7000                         NaN
# 7001                         NaN
# 7002                         NaN
# 7003                         NaN
#
#                                        relative_results  \
# 0                                                  None
# 1                                                  None
# 2                                                  None
# 3                                                  None
# 4                                                  None
# ...                                                 ...
# 6999  [0x8640bf23db6b3db1:0xdd2ab824e8bc3d77, 0x8640...
# 7000  [0x8641216a8691951d:0xc21f63d4676e5750, 0x8640...
# 7001  [0x8640c16a2a68446f:0x71dd67a5610c9b2a, 0x8640...
# 7002  [0x8640dcc9415d5983:0x9adb4218b9274d, 0x8640bf...
# 7003  [0x8640964f1b237f4f:0x9e31499d0815491c, 0x8640...
#
#                                                     url  \
# 0     https://www.google.com/maps/place//data=!4m2!3...
# 1     https://www.google.com/maps/place//data=!4m2!3...
# 2     https://www.google.com/maps/place//data=!4m2!3...
# 3     https://www.google.com/maps/place//data=!4m2!3...
# 4     https://www.google.com/maps/place//data=!4m2!3...
# ...                                                 ...
# 6999  https://www.google.com/maps/place//data=!4m2!3...
# 7000  https://www.google.com/maps/place//data=!4m2!3...
# 7001  https://www.google.com/maps/place//data=!4m2!3...
# 7002  https://www.google.com/maps/place//data=!4m2!3...
# 7003  https://www.google.com/maps/place//data=!4m2!3...
#
#                                                    text
# 0     Yes 🙌🏽. I got the curry chicken with a number ...
# 1     This food isn’t worth two nickels rubbed toget...
# 2     I brought four kids in who all wanted to taste...
# 3     GREEN SAUCE VERY SPICY. ONIONS VERY SPICY. GOO...
# 4     I got 4 varieties of boneless wings. All good ...
# ...                                                 ...
# 6999  I am a big fan of places that have a great atm...
# 7000  Krispy Kreme is my favorite donut shop! I love...
# 7001  Poor service, bad taste in food, and items on ...
# 7002  Gorilla Go Go Curry is a Japanese curry place ...
# 7003  It’s a Texan tradition to come down to the rod...
#
# [7004 rows x 16 columns]

# %%
def concat_dict_values(d):
    if d is None:
        return ''
    return ', '.join([f"{' '.join(value)}" for key, value in d.items()])


doc_df['doc_information'] = doc_df['description'].fillna(' ') + ' ' + doc_df['category'].apply(lambda x: ' '.join(x) if isinstance(x, list) else str(x)) + ' ' + doc_df['MISC'].apply(concat_dict_values) + doc_df['text'].fillna('')

# %%
doc_df.shape
# Out:
# (7004, 17)

# %%
doc_df = doc_df.drop_duplicates(subset='gmap_id', keep='first')
doc_df.reset_index(drop=True, inplace=True)

# %%
doc_df.shape
# Out:
# (6999, 17)

# %%
import pickle
with open('restaurent_docs.pickle', 'wb') as f:
    pickle.dump(doc_df, f)
